# %% [markdown]
# <a href="https://colab.research.google.com/github/Murali56-source/data-science---owner/blob/main/sdc2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={'a':10,'b':20,'c':30}
series=pd.series(data)
print(series['a'])
print(series[['a','c']])
print('---------')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-823cf2c932fc> in <cell line: 4>()
#       2 import numpy as np
#       3 data={'a':10,'b':20,'c':30}
# ----> 4 series=df.series(data)
#       5 print(series['a'])
#       6 print(series[['a','c']])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'series'

# %%
import pandas as pd
df=pd.read_csv("/content/energy.csv")
df
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv

path="/content/energy.csv"
electricity=pd.read_csv(path)

print(electricity)
print(electricity.shape)
print(electricity.head(5))
print(electricity.tail(4))
print(electricity.info())
print(electricity.describe())

print("Column Data")
print("electricity.columns")

print(electricity[electricity['State'].str.startswith('M')])
print(electricity[electricity['State'].str.endswith('M')])
rcb=electricity[electricity['State']=='Manipur']
print(electricity[electricity['State']=='Manipur'])
print(len(rcb))

print(electricity.sort_values(by='State'))

print(np.max(electricity['Consumption']))
print(np.min(electricity['Consumption']))
print(np.mean(electricity['Consumption']))
print(np.median(electricity['Consumption']))
print(np.std(electricity['Consumption']))
print(np.var(electricity['Consumption']))

print(electricity[electricity['State']=='Andhra']['Consumption'].max())
print(electricity[electricity['State']=='Andhra']['Consumption'].mean())

state1_data=electricity[electricity.State=='Andhra']
print("Andhra Data")
print(state1_data)
state2_data=electricity[electricity['State']=='Karnataka']

state4_data=electricity[electricity['State']=='Telengana']
state5_data=electricity[electricity['State']=='Tripura']


#line chart
fig, axes=plt.subplots(2)
axes[0].plot(state1_data['Date'],state1_data['Consumption'],marker='*')
axes[1].plot(state2_data['Date'],state2_data['Consumption'],marker='*')

fig1,axes1=plt.subplots(2)
axes1[0].bar(state4_data['Date'],state1_data['Consumption'],color='green')
axes1[1].bar(state5_data['Date'],state2_data['Consumption'],color='red')

fig2,axes2=plt.subplots(2)
axes2[0].scatter(state4_data['Date'],state1_data['Consumption'],color='green')
axes2[1].scatter(state5_data['Date'],state2_data['Consumption'],color='red')

#pie chart
fig2,axes2=plt.subplots(2)
state1='Andhra'
state2='Karnataka'

labels=[state1,state2]
state1_total=electricity[electricity['state']==state1]
state2_total=electricity[electricity['state']==state]


energy=[state1_total,state2_total]
axes2[0].pie(energy,labels=['Andhra','Karnataka'],colors=['green','red'],autopct='%1.1f%%')
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]
# (100, 3)
#          Date        State  Consumption
# 0  01-01-2024    Tamilnadu       347.25
# 1  02-01-2024      Manipur       605.12
# 2  03-01-2024    Telengana       444.63
# 3  04-01-2024  Pondicherry       974.54
# 4  05-01-2024    Tamilnadu       864.02
#           Date        State  Consumption
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         100 non-null    object
#  1   State        100 non-null    object
#  2   Consumption  100 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 2.5+ KB
# None
#        Consumption
# count   100.000000
# mean    534.090400
# std     245.341678
# min     100.470000
# 25%     321.570000
# 50%     517.075000
# 75%     726.215000
# max     997.970000
# Column Data
# electricity.columns
#           Date    State  Consumption
# 1   02-01-2024  Manipur       605.12
# 18  19-01-2024  Mizoram       643.98
# 21  22-01-2024  Manipur       948.57
# 22  23-01-2024  Manipur       638.98
# 37  07-02-2024  Manipur       682.92
# 41  11-02-2024  Manipur       248.19
# 44  14-02-2024  Mizoram       723.19
# 60  01-03-2024  Manipur       469.93
# 67  08-03-2024  Manipur       597.60
# 70  11-03-2024  Manipur       432.69
# 80  21-03-2024  Mizoram       726.23
# Empty DataFrame
# Columns: [Date, State, Consumption]
# Index: []
#           Date    State  Consumption
# 1   02-01-2024  Manipur       605.12
# 21  22-01-2024  Manipur       948.57
# 22  23-01-2024  Manipur       638.98
# 37  07-02-2024  Manipur       682.92
# 41  11-02-2024  Manipur       248.19
# 60  01-03-2024  Manipur       469.93
# 67  08-03-2024  Manipur       597.60
# 70  11-03-2024  Manipur       432.69
# 8
#           Date        State  Consumption
# 97  07-04-2024       Andhra       305.70
# 42  12-02-2024       Andhra       580.68
# 10  11-01-2024       Andhra       199.80
# 25  26-01-2024       Andhra       661.92
# 83  24-03-2024       Andhra       298.22
# ..         ...          ...          ...
# 85  26-03-2024           UP       828.55
# 26  27-01-2024           UP       366.07
# 96  06-04-2024           UP       726.21
# 13  14-01-2024  Uttarakhand       906.19
# 50  20-02-2024  Uttarakhand       463.45
#
# [100 rows x 3 columns]
# 997.97
# 100.47
# 534.0903999999999
# 517.075
# 244.11188777247207
# 59590.61375184001
# 661.92
# 406.6133333333334
# Andhra Data
#           Date   State  Consumption
# 10  11-01-2024  Andhra       199.80
# 25  26-01-2024  Andhra       661.92
# 42  12-02-2024  Andhra       580.68
# 82  23-03-2024  Andhra       393.36
# 83  24-03-2024  Andhra       298.22
# 97  07-04-2024  Andhra       305.70
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-57b04f479cee> in <cell line: 65>()
#      63
#      64 labels=[state1,state2]
# ---> 65 state1_total=electricity[electricity['state']==state1]
#      66 state1_total=state1_data['Consumption'].sum()
#      67
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'state'

# %%
import pandas as pd
fig1,axes1=pltsubplots(2)
